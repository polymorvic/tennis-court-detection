# %%
import json
from src.utils.annotations import TennisCourtAnnotationCollection

# %%
a = TennisCourtAnnotationCollection.from_raw_dir('../data/label-studio-annotations')

# %%
a.cleaned_annotations['01_18.png'].key_points
# Out:
# [KeyPointAnnotation(label=<TennisCourtKeyPointLabel.left_outer_netline_point: 'left_outer_netline_point'>, coordinates=KeyPointCoordinates(x=26.480030215041822, y=36.549182013890466)),
#  KeyPointAnnotation(label=<TennisCourtKeyPointLabel.left_inner_netline_point: 'left_inner_netline_point'>, coordinates=KeyPointCoordinates(x=31.809498034050748, y=36.549182013890466)),
#  KeyPointAnnotation(label=<TennisCourtKeyPointLabel.netline_service_point: 'netline_service_point'>, coordinates=KeyPointCoordinates(x=47.98610038571989, y=36.739150264491606)),
#  KeyPointAnnotation(label=<TennisCourtKeyPointLabel.right_inner_netline_point: 'right_inner_netline_point'>, coordinates=KeyPointCoordinates(x=64.15311478327409, y=36.97703964593465)),
#  KeyPointAnnotation(label=<TennisCourtKeyPointLabel.right_outer_netline_point: 'right_outer_netline_point'>, coordinates=KeyPointCoordinates(x=69.37878052716772, y=36.62020557377008)),
#  KeyPointAnnotation(label=<TennisCourtKeyPointLabel.left_service_point: 'left_service_point'>, coordinates=KeyPointCoordinates(x=28.487563798462762, y=51.92442244660619)),
#  KeyPointAnnotation(label=<TennisCourtKeyPointLabel.centre_service_point: 'centre_service_point'>, coordinates=KeyPointCoordinates(x=47.94153230209188, y=52.00371890708719)),
#  KeyPointAnnotation(label=<TennisCourtKeyPointLabel.left_outer_baseline_point: 'left_outer_baseline_point'>, coordinates=KeyPointCoordinates(x=67.35093272209298, y=52.0433671373277)),
#  KeyPointAnnotation(label=<TennisCourtKeyPointLabel.left_outer_baseline_point: 'left_outer_baseline_point'>, coordinates=KeyPointCoordinates(x=14.560037664707659, y=71.90713048782223)),
#  KeyPointAnnotation(label=<TennisCourtKeyPointLabel.left_inner_baseline_point: 'left_inner_baseline_point'>, coordinates=KeyPointCoordinates(x=23.25081397217084, y=72.06572340878427)),
#  KeyPointAnnotation(label=<TennisCourtKeyPointLabel.right_inner_baseline_point: 'right_inner_baseline_point'>, coordinates=KeyPointCoordinates(x=72.47626233931486, y=72.06572340878427)),
#  KeyPointAnnotation(label=<TennisCourtKeyPointLabel.right_outer_baseline_point: 'right_outer_baseline_point'>, coordinates=KeyPointCoordinates(x=80.98876631226597, y=72.06572340878427))]

# %%
a.filter_by_image('01_01.png')
# Out:
# ImageAnnotation(image=ImageMetaData(name='01_01.png', width=1918, height=1078, file_origin='Mecz_1.json'), key_points=[KeyPointAnnotation(label=<TennisCourtKeyPointLabel.left_outer_netline_point: 'left_outer_netline_point'>, coordinates=KeyPointCoordinates(x=29.726426190066864, y=38.45417606094148)), KeyPointAnnotation(label=<TennisCourtKeyPointLabel.left_inner_netline_point: 'left_inner_netline_point'>, coordinates=KeyPointCoordinates(x=34.54808485844803, y=38.782615778376)), KeyPointAnnotation(label=<TennisCourtKeyPointLabel.right_inner_netline_point: 'right_inner_netline_point'>, coordinates=KeyPointCoordinates(x=64.25929384661177, y=39.106134967342165)), KeyPointAnnotation(label=<TennisCourtKeyPointLabel.right_outer_netline_point: 'right_outer_netline_point'>, coordinates=KeyPointCoordinates(x=68.98995360765669, y=38.81529988852254)), KeyPointAnnotation(label=<TennisCourtKeyPointLabel.centre_service_point: 'centre_service_point'>, coordinates=KeyPointCoordinates(x=49.34699602742698, y=52.82209335827838)), KeyPointAnnotation(label=<TennisCourtKeyPointLabel.netline_service_point: 'netline_service_point'>, coordinates=KeyPointCoordinates(x=49.498128537831946, y=38.89028426103788)), KeyPointAnnotation(label=<TennisCourtKeyPointLabel.left_service_point: 'left_service_point'>, coordinates=KeyPointCoordinates(x=31.558939815427365, y=52.78228164490416)), KeyPointAnnotation(label=<TennisCourtKeyPointLabel.right_service_point: 'right_service_point'>, coordinates=KeyPointCoordinates(x=67.17438622413798, y=53.29966591256483)), KeyPointAnnotation(label=<TennisCourtKeyPointLabel.left_outer_baseline_point: 'left_outer_baseline_point'>, coordinates=KeyPointCoordinates(x=18.949218912031732, y=70.87141173882259)), KeyPointAnnotation(label=<TennisCourtKeyPointLabel.left_inner_baseline_point: 'left_inner_baseline_point'>, coordinates=KeyPointCoordinates(x=26.726294173844757, y=71.152368772475)), KeyPointAnnotation(label=<TennisCourtKeyPointLabel.right_inner_baseline_point: 'right_inner_baseline_point'>, coordinates=KeyPointCoordinates(x=71.84912170812032, y=71.50356506454052)), KeyPointAnnotation(label=<TennisCourtKeyPointLabel.right_outer_baseline_point: 'right_outer_baseline_point'>, coordinates=KeyPointCoordinates(x=79.62619696993335, y=71.64404358136674))])

# %%
a.validate()
# Out:
# 01_18.png
# 05_18.png
# 05_21.png
# 06_15.png
# 07_28.png
# 08_27.png

# %%
with open('../data/label-studio-annotations/Mecz_1.json', 'r') as f:
    data = json.load(f)

# %%
len(data[0]['annotations'][0]['result'])
# Out:
# 12

# %%
data[0]['annotations'][0]['result']
# Out:
# [{'original_width': 1918,
#   'original_height': 1078,
#   'image_rotation': 0,
#   'value': {'x': 29.726426190066864,
#    'y': 38.45417606094148,
#    'width': 0.22526805435688896,
#    'keypointlabels': ['left_outer_netline_point']},
#   'id': 'gNCAEfeS3o',
#   'from_name': 'kp-1',
#   'to_name': 'img-1',
#   'type': 'keypointlabels',
#   'origin': 'manual'},
#  {'original_width': 1918,
#   'original_height': 1078,
#   'image_rotation': 0,
#   'value': {'x': 34.54808485844803,
#    'y': 38.782615778376,
#    'width': 0.22526805435688896,
#    'keypointlabels': ['left_inner_netline_point']},
#   'id': 'sAkGBKEp2m',
#   'from_name': 'kp-1',
#   'to_name': 'img-1',
#   'type': 'keypointlabels',
#   'origin': 'manual'},
#  {'original_width': 1918,
#   'original_height': 1078,
#   'image_rotation': 0,
#   'value': {'x': 64.25929384661177,
#    'y': 39.106134967342165,
#    'width': 0.22526805435688896,
#    'keypointlabels': ['right_inner_netline_point']},
#   'id': '4lzuQZ9ftB',
#   'from_name': 'kp-1',
#   'to_name': 'img-1',
#   'type': 'keypointlabels',
#   'origin': 'manual'},
#  {'original_width': 1918,
#   'original_height': 1078,
#   'image_rotation': 0,
#   'value': {'x': 68.98995360765669,
#    'y': 38.81529988852254,
#    'width': 0.22526805435688896,
#    'keypointlabels': ['right_outer_netline_point']},
#   'id': 'a43bF_1i4K',
#   'from_name': 'kp-1',
#   'to_name': 'img-1',
#   'type': 'keypointlabels',
#   'origin': 'manual'},
#  {'original_width': 1918,
#   'original_height': 1078,
#   'image_rotation': 0,
#   'value': {'x': 49.34699602742698,
#    'y': 52.82209335827838,
#    'width': 0.22526805435688896,
#    'keypointlabels': ['centre_service_point']},
#   'id': 'ZzVy7Yn2X4',
#   'from_name': 'kp-1',
#   'to_name': 'img-1',
#   'type': 'keypointlabels',
#   'origin': 'manual'},
#  {'original_width': 1918,
#   'original_height': 1078,
#   'image_rotation': 0,
#   'value': {'x': 49.498128537831946,
#    'y': 38.89028426103788,
#    'width': 0.22526805435688896,
#    'keypointlabels': ['netline_service_point']},
#   'id': 'zMxqjy2OAb',
#   'from_name': 'kp-1',
#   'to_name': 'img-1',
#   'type': 'keypointlabels',
#   'origin': 'manual'},
#  {'original_width': 1918,
#   'original_height': 1078,
#   'image_rotation': 0,
#   'value': {'x': 31.558939815427365,
#    'y': 52.78228164490416,
#    'width': 0.22526805435688896,
#    'keypointlabels': ['left_service_point']},
#   'id': 'ym8wsqrg90',
#   'from_name': 'kp-1',
#   'to_name': 'img-1',
#   'type': 'keypointlabels',
#   'origin': 'manual'},
#  {'original_width': 1918,
#   'original_height': 1078,
#   'image_rotation': 0,
#   'value': {'x': 67.17438622413798,
#    'y': 53.29966591256483,
#    'width': 0.22526805435688896,
#    'keypointlabels': ['right_service_point']},
#   'id': 'U0AbDdyCOG',
#   'from_name': 'kp-1',
#   'to_name': 'img-1',
#   'type': 'keypointlabels',
#   'origin': 'manual'},
#  {'original_width': 1918,
#   'original_height': 1078,
#   'image_rotation': 0,
#   'value': {'x': 18.949218912031732,
#    'y': 70.87141173882259,
#    'width': 0.22526805435688896,
#    'keypointlabels': ['left_outer_baseline_point']},
#   'id': 'YRXReTlSKG',
#   'from_name': 'kp-1',
#   'to_name': 'img-1',
#   'type': 'keypointlabels',
#   'origin': 'manual'},
#  {'original_width': 1918,
#   'original_height': 1078,
#   'image_rotation': 0,
#   'value': {'x': 26.726294173844757,
#    'y': 71.152368772475,
#    'width': 0.22526805435688896,
#    'keypointlabels': ['left_inner_baseline_point']},
#   'id': 'nFE5y34lxe',
#   'from_name': 'kp-1',
#   'to_name': 'img-1',
#   'type': 'keypointlabels',
#   'origin': 'manual'},
#  {'original_width': 1918,
#   'original_height': 1078,
#   'image_rotation': 0,
#   'value': {'x': 71.84912170812032,
#    'y': 71.50356506454052,
#    'width': 0.22526805435688896,
#    'keypointlabels': ['right_inner_baseline_point']},
#   'id': 'a4YvjmCZX7',
#   'from_name': 'kp-1',
#   'to_name': 'img-1',
#   'type': 'keypointlabels',
#   'origin': 'manual'},
#  {'original_width': 1918,
#   'original_height': 1078,
#   'image_rotation': 0,
#   'value': {'x': 79.62619696993335,
#    'y': 71.64404358136674,
#    'width': 0.22526805435688896,
#    'keypointlabels': ['right_outer_baseline_point']},
#   'id': 'ixvJhBVG02',
#   'from_name': 'kp-1',
#   'to_name': 'img-1',
#   'type': 'keypointlabels',
#   'origin': 'manual'}]

# %%
[
    {
        'label1': {
            'x': 0.0,
            'y': 0.0
        }
    },
    {
        'label2': {
            'x': 0.0,
            'y': 0.0
        }
    },

]
# Out:
# [{'label1': {'x': 0.0, 'y': 0.0}}, {'label2': {'x': 0.0, 'y': 0.0}}]
