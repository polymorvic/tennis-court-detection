# %%
import pandas as pd
from cvgeomkit.geometry.lines import Line
from src.schemas.config import ServiceSide

# %%
ss = ServiceSide('right')

# %%
if ss.value == 'left':
    print('ok')

# %%
line = Line(slope=10, intercept=20)

# %%
a = []

# %%
if a:
    print('ok')

# %%
256/384
# Out:
# 0.6666666666666666

# %%
from src.utils.annotations import TennisCourtAnnotationCollection
annotation_path = 'data/annotations.json'

# %%
tcac = TennisCourtAnnotationCollection.from_clean_file(annotation_path)

# %%
ann = tcac.filter_by_image('01_01.png')

# %%
ann.key_points
# Out:
# [KeyPointAnnotation(label=<TennisCourtKeyPointLabel.left_outer_netline_point: 'left_outer_netline_point'>, coordinates=KeyPointCoordinates(x=29.726426190066864, y=38.45417606094148)),
#  KeyPointAnnotation(label=<TennisCourtKeyPointLabel.left_inner_netline_point: 'left_inner_netline_point'>, coordinates=KeyPointCoordinates(x=34.54808485844803, y=38.782615778376)),
#  KeyPointAnnotation(label=<TennisCourtKeyPointLabel.right_inner_netline_point: 'right_inner_netline_point'>, coordinates=KeyPointCoordinates(x=64.25929384661177, y=39.106134967342165)),
#  KeyPointAnnotation(label=<TennisCourtKeyPointLabel.right_outer_netline_point: 'right_outer_netline_point'>, coordinates=KeyPointCoordinates(x=68.98995360765669, y=38.81529988852254)),
#  KeyPointAnnotation(label=<TennisCourtKeyPointLabel.centre_service_point: 'centre_service_point'>, coordinates=KeyPointCoordinates(x=49.34699602742698, y=52.82209335827838)),
# ...

# %%
left_service_point = tcac.get_key_point_for_image("01_01.png", "left_service_point")
right_service_point = tcac.get_key_point_for_image("01_01.png", "right_service_point")

# %%
left_service_point.coordinates.as_array
# Out:
# array([31.55893982, 52.78228164])

# %%
left_service_point
import numpy as np

# %%
import pandas as pd

# %%
pd.DataFrame(['s', 1, 2], columns=['ss'])
# Out:
#   ss
# 0  s
# 1  1
# 2  2

# %%
from cvgeomkit.geometry.lines import Line

# %%
l1 = Line(3, 100)
l2 = Line(5, 10)
l3 = Line(5, 10)

# %%
if l3 in {l1, l2}:
    print('dubel')
# Out:
# dubel

# %%
from pathlib import Path
import cv2
pics_dir = Path('data/pics')

heights = []
for file in pics_dir.glob('*.png'):
    img = cv2.imread(file)
    h = img.shape[0]

    heights.append(h)

# %%
import numpy as np
np.array(heights).mean()
# Out:
# np.float64(1077.7966666666666)

# %%
917 / 1077.7966666666666
# Out:
# 0.8508098311679074
